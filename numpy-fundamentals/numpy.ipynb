# %% [markdown]
# How to import the numpy library
# the numpy library = Numerical Python

# %%
#importing numpy
import numpy as np

# %% [markdown]
# Manipulating an Array using nump

# %%
arr = [1,2,3]

def list_to_array(arr):

    return np.array(arr)

print(list_to_array(arr))
# Out:
# [1 2 3]
