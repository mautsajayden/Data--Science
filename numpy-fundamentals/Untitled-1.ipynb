# %%
import pandas as pd 
import numpy as np
from sklearn.tree import DecisionTreeRegressor as d_t_r


data_file = pd.read_csv("melbourne-housing\melb_data.csv")

df = pd.DataFrame(data_file)

filter_data_file = data_file.dropna(axis=0)

X = [ 'Rooms',' Bathroom', ' Landsize','YearBuilt','Lattitude',
       'Longtitude', 'Regionname']

y = data_file.Price

data_model = d_t_r(random_state=1)

data_model.

print(data_file.columns)
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\mauts\AppData\Local\Temp\ipykernel_10504\233798126.py:6: SyntaxWarning: invalid escape sequence '\m'
#   data_file = pd.read_csv("melbourne-housing\melb_data.csv")
