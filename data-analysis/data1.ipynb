# %%
import unicodecsv 

with open('enrollments.csv','rb') as f :

    reader = unicodecsv.DictReader(f)
    
    enrollments = list(reader)

enrollments[0]

# %% [markdown]
# Reading data from daily engagement

# %%
with open('daily_engagement.csv','rb') as de :
    reader = unicodecsv.DictReader(de)
    
    daily_reader = list(reader)
    
daily_reader[0]

# %% [markdown]
# Reading data in the project submission csv

# %%
with open('project_submissions.csv','rb') as p_s:
    reader = unicodecsv.DictReader(p_s)
    
    project_subs = list(reader)
    
project_subs[0]
