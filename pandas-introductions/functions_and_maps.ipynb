# %%
# .describe helps provide simple summary functions and restructure the data 
# reviews - has the dataFrame

#reviews.points.describe()

#reviews.points.mean()

#reviews.taster_name.unique()

#reviews.taster_name.value_counts()

#maps used to create new represenattions of the data 

review_points_mean = review.points.mean()
review.points.map(lambda p: p - review_points_mean)
