# %%
import pandas as pd 

df = pd.read_csv("melbourne-housing\melb_data.csv")

# %%
#using .head() gives you the top 5 rows of your datafram 
#print(df.head())
#using .tail() gives you the bottom 5 rows of your data frame
#print(df.tail())

#using .info() tellas you about the dataframe 
#print(df.info())

#using the .describe() gives you the statistical viewpoint of your data 
print(df.describe())

#using the .columns gives you a list with the name of your columns 
print(df.columns)

#using the .index gives you a the range you can use to step over your data frame using a loop 
print(df.index)

# %%
df.columns

#indexing by columns 
#df[['Rooms','Type']]

#indexing by rows 
df.iloc[10]

# %% [markdown]
# Filtering

# %%
df.columns

# %%
#showing data only in thus catergory of the surburb 'Williamstown'
df[df["Suburb"]=='Williamstown']

# %%
#shows what the name in the str catergory startsswith 
df[df['Suburb'].str.startswith('B')]

#shows what the name in the str category ends with 
df[df['Regionname'].str.endswith('n')]

# %% [markdown]
# how to locate the row of an item

# %%
#you use .loc
df.loc[df['Suburb']=='Williamstown']
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 6485   Williamstown       4 Freyer St      4    h  1325000.0      S
# 6486   Williamstown       46 Pasco St      4    h  1400000.0      S
# 6487   Williamstown     54 Twyford St      3    h  1535000.0      S
# 6488   Williamstown  2/20 Victoria St      3    u   890000.0      S
# 6489   Williamstown    35 Chandler St      4    h  1400000.0     PI
# ...             ...               ...    ...  ...        ...    ...
# 13084  Williamstown    54 Victoria St      5    h  2550000.0     PI
# 13329  Williamstown   146 Ferguson St      3    h   832000.0      S
# 13576  Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  Williamstown       83 Power St      3    h  1170000.0      S
# 13578  Williamstown      96 Verdon St      4    h  2500000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 6485   hockingstuart   3/09/2016       8.0    3016.0  ...       2.0  1.0
# ...
